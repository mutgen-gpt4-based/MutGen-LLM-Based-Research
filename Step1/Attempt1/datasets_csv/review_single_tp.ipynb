# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_C5_clean.csv")

# %%
df
# Out:
#                                                  fixed  \
# 0    public void METHOD_1 ( boolean VAR_1 ) { VAR_2...
# 1    public void METHOD_1 ( android.view.View VAR_1...
# 2    public void METHOD_1 ( ) { this . VAR_1 = this...
# 3    public void METHOD_1 ( ) { VAR_1 = new TYPE_1 ...
# 4    public void METHOD_1 ( java.lang.String VAR_1 ...
# ..                                                 ...
# 798  public void METHOD_1 ( android.content.Context...
# 799  public void METHOD_1 ( TYPE_1 VAR_1 , int VAR_...
# 800  public void METHOD_1 ( ) { VAR_1 = new TYPE_1 ...
# 801  private void METHOD_1 ( ) { VAR_1 = 0 ; VAR_2 ...
# 802  public boolean METHOD_1 ( TYPE_1 VAR_1 , int V...
#
#                                                  buggy  \
# 0    public void METHOD_1 ( boolean VAR_1 ) { VAR_2...
# 1    public void METHOD_1 ( android.view.View VAR_1...
# 2                         public void METHOD_1 ( ) { }
# 3    public void METHOD_1 ( ) { VAR_1 = new TYPE_1 ...
# ...
